# %%
# %matplotlib inline

# %%
import numpy as np
import networkx as nx
from matplotlib import pyplot as plt

# %%
A = np.load("./train_A.npy", allow_pickle = True)

# %%
nx.draw(nx.from_numpy_array(A[2]), node_color = "black", node_size = 20)

# %%
E = np.load("./train_E.npy", allow_pickle = True)

# %%
plt.imshow(E[2], vmin = -1, vmax = 1)

# %%
np.mean(np.vstack([e[:, :8] for e in E]), axis = 0)
# Out:
# array([ 4.62975931e+00,  1.73859516e-01, -7.29299874e-16,  5.05509358e-17,
#        -1.58675952e-17,  1.99353794e-17,  7.70459630e-18, -8.00891794e-18])

# %%
np.mean(np.vstack(E), axis = 0)
